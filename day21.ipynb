# %%
set1={"ajith","kumar","mass","venkata"}
set2={"ajith","kumar"}

print(type(set1))
set2.add("mass")
print(set2)
# Out:
# <class 'set'>
# {'mass', 'ajith', 'kumar'}

# %%
set1.difference(set2)
# Out:
# {'venkata'}

# %%
set2
# Out:
# {'ajith', 'kumar', 'mass'}

# %%
set2.intersection(set1)
# Out:
# {'ajith', 'kumar', 'mass'}

# %%
dict1 = {"id1":"ajith"}
dict2= {"id2": "Gowtham"}
dict3={"id3":"abju"}
type(dict1)
# Out:
# dict

# %%
gl = {"malec":dict1,"malel":dict3}
print(gl)
# Out:
# {'malec': {'id1': 'ajith'}, 'malel': {'id3': 'abju'}}

# %%
print(gl["malec"]["id1"])
# Out:
# ajith

# %%
tup = ("ajith","ajith","kumar","gowtham")
print(tup.count("ajith"))
