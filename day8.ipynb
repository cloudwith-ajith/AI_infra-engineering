# %%
#pickling--it's a kind of wrap to use to bind the code you have returned 

import numpy as np
import pandas as pd

# file_name.to_pickle("file naem to give")
dfexcel.to_pickle("df_excel")
df  = pd.read_pickle("df_excel")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 import pandas as pd
#       6 # file_name.to_pickle("file naem to give")
# ----> 7 df_excel.to_pickle("df_excel")
#       8 df  = pd.read_pickle("df_excel")
#       9 df.head()
#
# NameError: name 'df_excel' is not defined

# %%
filename.to_pickle("name of the file")
var_name = pd.read_pickle("name of the file")

var_name.head()

# %%
var_name = pd.read_excel()

# %%
# reading the HTML file

var_name = pd.read_html(url,match=" ",header = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # reading the HTML file
# ----> 3 var_name = pd.read_html(url,match=" ",header = 0)
#
# NameError: name 'url' is not defined

# %%
# Reading the JSON files
var_name = pd.read_json("file name / url")
var_name.head()

# %%
#while converting the JSON file to another format, use the parameter called --> orient = records

var_name.to_json(orient = "records")

# %%
#csv

pd.read_csv("filename",sep=',',escapechar='\t',)
