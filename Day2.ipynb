# %%
a = 10
id(a)
# Out:
# 140712972494024

# %%
a = 10 
id(a)
print (id(10))
# Out:
# 140712972494024

# %%
del a

# %%
a =12
id (a)
# Out:
# 140712972494088

# %%
x= float(10)
type(x)
# Out:
# float

# %%
print(x)
# Out:
# 10.0

# %%
liar = [1,2,3,4,4,6]
liar[4]=5
print(liar)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
data = b"ajithkumar"
print(data)
# Out:
# b'ajithkumar'

# %%
data = b"ajith kumar"
view = memoryview(data)
print(view)

# %%
print(id(data))
# Out:
# 2731628013600

# %%
dic ={
    "id_1": "Ajith",
    "number": 8220419685,
    "id_2": "kumar",
    "number": 8526701234
}

print(type(dic))
# Out:
# <class 'dict'>

# %%
print(dic['id_1'])
# Out:
# Ajith

# %%
set1= {"ajith",  "ram",  "manas"}
print(set1)
# Out:
# {'ajith', 'manas', 'ram'}

# %%
a = 87
print(bool(a))
# Out:
# True

# %%
#type casting
a = int(9.6)
print(a) # here a is 9
b = float(1)
print(b) # here b is 1.0
c = str(32)
print(type(c)) # here c is str
# Out:
# 9
# 1.0
# <class 'str'>

# %%
x =repr (23)
print(x)
# Out:
# 23

# %%
#eval(), which is used to do math in the string 
a = "2+(2*3)"
print(eval(a))
# Out:
# 8

# %%
def printnumber(x):
    print(x)

a = int(input())
printnumber(a)
# Out:
#  23
# 23

# %%
age = int(input("Enter the age:"))
if age >= 18:
    print("adult")
else:
    print("not adult")
# Out:
# Enter the age: -5
# not adult
