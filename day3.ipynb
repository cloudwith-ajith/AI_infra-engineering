# %%
a = 89 
print(type(a))
# Out:
# <class 'int'>

# %%
b = 3.4
c = 3+6j
d = "ajith"
e = [1,2,3,4,5]
f = {1,2,3,4,5}
g = (1,2,3,4,5)
t = {"name":"ajith","age":22}

print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
print(type(t))
# Out:
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'set'>
# <class 'tuple'>
# <class 'dict'>

# %%
a  = "ajith"
b = "kumar"
print("hi first name is{} and the seconf name is {}",a,b)
# Out:
# hi first name is{} and the seconf name is {} ajith kumar

# %%
a  = "ajith"
b = "kumar"
print("hi first name is {} and the second name is {}".format(a,b))
# Out:
# hi first name is ajith and the second name is kumar

# %%
a = "ajith"
print(len(a))
# Out:
# 5

# %%
m = [1,2,3,4,5,6,7,8]
print(len(m))
# Out:
# 8

# %%
print(id(a)) # id() function used to get the memory address of the variable
# Out:
# 1518978094864

# %%
#del(m) is the inbuild function 
m =2
print(m) # used to delete the variable in the Python program
# Out:
# 2

# %%
#typcasting 
a = input("enter the value")
#b = int(a)
print(type(a))
# Out:
# enter the value 45
# <class 'str'>

# %%
# multiple assignment 
a=b=c =100
print(a,b,c)
# Out:
# 100 100 100

# %%
a = "ajithkumar"
print(a[::-1])
# Out:
# ramukhtija
